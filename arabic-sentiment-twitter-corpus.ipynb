# %% [markdown]
# ***Load important Libraries***

# %%
import pandas as pd
pd.set_option('display.max_colwidth', 100000)
from IPython.display import display
import os
import eli5

# sklearn
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import GaussianNB
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score

# %% [markdown]
# **helper for displaying the DataFrame**
#
#
# helper for displaying a DataFrame in text classification is useful for visualizing the dataset, aiding in data cleaning, conducting exploratory data analysis (EDA), feature engineering, evaluating model performance, and creating clear documentation and reports.

# %%
# a helper for displaying the DataFrame
def highlight_col(x, df):
    # set by condition
    pos_mask = (df['label'] == 'pos')
    neg_mask = (df['label'] == 'neg')
    x = pd.DataFrame('', index=df.index, columns=df.columns)
    x.loc[pos_mask] = 'background-color: #e6ffe6'
    x.loc[neg_mask] = 'background-color: #ffe6e6'
    return x

# %% [markdown]
# **Load the Dataset(the train data)**

# %%
# read tsv files for train
POS_PATH = os.path.join(os.getcwd(), 'Data', '/kaggle/input/arabic-sentiment-twitter-corpus/train_Arabic_tweets_positive_20190413.tsv')
NEG_PATH = os.path.join(os.getcwd(), 'Data', '/kaggle/input/arabic-sentiment-twitter-corpus/train_Arabic_tweets_negative_20190413.tsv')

df_pos = pd.read_csv(POS_PATH, sep='\t', header=None)
df_neg = pd.read_csv(NEG_PATH, sep='\t', header=None)

# Concate both
df_train = pd.concat([df_pos, df_neg], ignore_index=True)
df_train.columns = ['label', 'tweet']

df_train.head()
# Out:
#   label  \
# 0   pos
# 1   pos
# 2   pos
# 3   pos
# 4   pos
#
#                                                                                                                 tweet
# 0                   نحن الذين يتحول كل ما نود أن نقوله إلى دعاء لله، لا تبحثوا فينا عن قوة، إننا مكسورون، القوة التي…
# 1                                         وفي النهاية لن يبقىٰ معك آحدإلا من رأىٰ الجمال في روحك أماالمنبهرون بالمظا…
# 2                                                                                                     من الخير نفسه 💛
# 3  #زلزل_الملعب_نصرنا_بيلعب كن عالي الهمه ولا ترضى بغير القمه مجرد ساعات لاستعادة الصداره💛💙 الوصول إلى القمه مهارة ت…
# 4                      الشيء الوحيد الذي وصلوا فيه للعالمية هو : المسيار ..! . ترى كانوا يشجعون ريال مدريد ضد النصر 🤣

# %%
df_train.tail()
# Out:
#       label  \
# 45270   neg
# 45271   neg
# 45272   neg
# 45273   neg
# 45274   neg
#
#                                                                                                                tweet
# 45270           كيف ترى أورانوس لو كان يقع مكان القمر ؟ 💙💙 كوكب بعدا عن الشمس يبلغ قطره كم لو كان كرة مجوفة لأستوعب…
# 45271                                                                                              احسدك على الايم 💔
# 45272                                                                                        لأول مرة ما بنكون سوا 💔
# 45273                                                                                             بقله ليش يا واطي 🤔
# 45274  قد طال صبري في النوى إذ تركتني كئيبا ؛ غريبا باكيا متوجعا 😔 ف يامهجتي ياروح قلبي ياراحتي آغثني ف قلبي كاد أن…

# %%
# No need more for them after concatenating
del df_pos, df_neg

# %%
# See Highlited DF with my custom function
df_tmp = df_train.sample(5)
df_tmp.style.apply(lambda x: highlight_col(x, df_tmp), axis=None)
# Out:
# <style type="text/css">
# #T_75c89_row0_col0, #T_75c89_row0_col1, #T_75c89_row2_col0, #T_75c89_row2_col1, #T_75c89_row3_col0, #T_75c89_row3_col1 {
#   background-color: #ffe6e6;
# }
# #T_75c89_row1_col0, #T_75c89_row1_col1, #T_75c89_row4_col0, #T_75c89_row4_col1 {
#   background-color: #e6ffe6;
# }
# </style>
# <table id="T_75c89">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75c89_level0_col0" class="col_heading level0 col0" >label</th>
#       <th id="T_75c89_level0_col1" class="col_heading level0 col1" >tweet</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75c89_level0_row0" class="row_heading level0 row0" >38635</th>
#       <td id="T_75c89_row0_col0" class="data row0 col0" >neg</td>
#       <td id="T_75c89_row0_col1" class="data row0 col1" >هه مش ينقص .. ت انعدم نهائيا 😣</td>
#     </tr>
#     <tr>
#       <th id="T_75c89_level0_row1" class="row_heading level0 row1" >6898</th>
#       <td id="T_75c89_row1_col0" class="data row1 col0" >pos</td>
#       <td id="T_75c89_row1_col1" class="data row1 col1" >انا مقلعش البنطلون غير في سياق الدراسه 😂</td>
#     </tr>
#     <tr>
#       <th id="T_75c89_level0_row2" class="row_heading level0 row2" >27981</th>
#       <td id="T_75c89_row2_col0" class="data row2 col0" >neg</td>
#       <td id="T_75c89_row2_col1" class="data row2 col1" >#الاتحاد_النصر الوضع بختصار 😏</td>
#     </tr>
#     <tr>
#       <th id="T_75c89_level0_row3" class="row_heading level0 row3" >44771</th>
#       <td id="T_75c89_row3_col0" class="data row3 col0" >neg</td>
#       <td id="T_75c89_row3_col1" class="data row3 col1" >Circus النسخة الكورية !! اوكيه عبالي ماراح يقربون من الاغاني اليابانية بس طبعا راضية عشانها تحمس مرة بموت 😭</td>
#     </tr>
#     <tr>
#       <th id="T_75c89_level0_row4" class="row_heading level0 row4" >4874</th>
#       <td id="T_75c89_row4_col0" class="data row4 col0" >pos</td>
#       <td id="T_75c89_row4_col1" class="data row4 col1" >#يسقط_حكم_تميم البلد بازط يا جدعان متعرفش الراجل من اللي مش راجل من المقنس والمش مقنس بلد مضروبه بخلاط الحجه فواكه…</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **load the dataset(the test data)**

# %%
# read tsv files for train
TEST_POS_PATH = os.path.join(os.getcwd(), 'Data', '/kaggle/input/arabic-sentiment-twitter-corpus/test_Arabic_tweets_positive_20190413.tsv')
TEST_NEG_PATH = os.path.join(os.getcwd(), 'Data', '/kaggle/input/arabic-sentiment-twitter-corpus/test_Arabic_tweets_negative_20190413.tsv')

df_test_pos = pd.read_csv(TEST_POS_PATH, sep='\t', header=None)
df_test_neg = pd.read_csv(TEST_NEG_PATH, sep='\t', header=None)

# Concate both
df_test = pd.concat([df_test_pos, df_test_neg], ignore_index=True)
df_test.columns = ['label', 'tweet']

df_test.head()
# Out:
#   label  \
# 0   pos
# 1   pos
# 2   pos
# 3   pos
# 4   pos
#
#                                                                                                                             tweet
# 0               #الهلال_الاهلي فوز هلالي مهم الحمد لله 💙 زوران كان بيسلم المباراة بعد تبديل كارييو بإنتظار الإتحاد بكرة يارب يار…
# 1                                                                                                            صباحك خيرات ومسرات 🌸
# 2                     #تأمل قال الله ﷻ :- _*​﴿بواد غير ذي زرع ﴾*_ 💫💫 ✍ " ~ومع ذلك هتف بالدعاء ﴿وارزقهم من الثمرات ﴾ مهماكانت ظرو…
# 3               😂😂 يا جدعان الرجاله اللي فوق ال دول خطر ع تويتر وربنا 😂مش اسلوب كل يومين يدخلي واحد قد جدي علشان يشقطني 😒 😹و عند…
# 4  رساله صباحيه : 💛 اللهم اسألك التوفيق في جميع امورنا واكتب لنا الفردوس نحن ووالدينا وجميع موتى المسلمين برحمتك يا ارحم الراحمين

# %%
# No need more for them after concatenating
del df_test_pos, df_test_neg

# %%
# See Highlited DF with my custom function
df_tmp = df_test.sample(5)
df_tmp.style.apply(lambda x: highlight_col(x, df_tmp), axis=None)
# Out:
# <style type="text/css">
# #T_c3e17_row0_col0, #T_c3e17_row0_col1, #T_c3e17_row1_col0, #T_c3e17_row1_col1, #T_c3e17_row4_col0, #T_c3e17_row4_col1 {
#   background-color: #ffe6e6;
# }
# #T_c3e17_row2_col0, #T_c3e17_row2_col1, #T_c3e17_row3_col0, #T_c3e17_row3_col1 {
#   background-color: #e6ffe6;
# }
# </style>
# <table id="T_c3e17">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3e17_level0_col0" class="col_heading level0 col0" >label</th>
#       <th id="T_c3e17_level0_col1" class="col_heading level0 col1" >tweet</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3e17_level0_row0" class="row_heading level0 row0" >7384</th>
#       <td id="T_c3e17_row0_col0" class="data row0 col0" >neg</td>
#       <td id="T_c3e17_row0_col1" class="data row0 col1" >المهم مشكور ع جهودك حاولت اضحك بس ماش والله ☹</td>
#     </tr>
#     <tr>
#       <th id="T_c3e17_level0_row1" class="row_heading level0 row1" >7236</th>
#       <td id="T_c3e17_row1_col0" class="data row1 col0" >neg</td>
#       <td id="T_c3e17_row1_col1" class="data row1 col1" >اذا الفيفا عارف هالشي غلط مش المفروض يتصرف ويتخذ اجراءه ولا الاتحاد السعودي اقوى منه ولا هاي الشوشرا…</td>
#     </tr>
#     <tr>
#       <th id="T_c3e17_level0_row2" class="row_heading level0 row2" >4509</th>
#       <td id="T_c3e17_row2_col0" class="data row2 col0" >pos</td>
#       <td id="T_c3e17_row2_col1" class="data row2 col1" >طبعة الروج 💋 هي العلامة اللي تعرف بها البنت نقابها اذا مقلوب او لا صحيح هالكلام ي بنات ؟! 🌚😂</td>
#     </tr>
#     <tr>
#       <th id="T_c3e17_level0_row3" class="row_heading level0 row3" >5203</th>
#       <td id="T_c3e17_row3_col0" class="data row3 col0" >pos</td>
#       <td id="T_c3e17_row3_col1" class="data row3 col1" >سورى بجد بس انتى قمر فشخ ❤ — 💖💖</td>
#     </tr>
#     <tr>
#       <th id="T_c3e17_level0_row4" class="row_heading level0 row4" >10113</th>
#       <td id="T_c3e17_row4_col0" class="data row4 col0" >neg</td>
#       <td id="T_c3e17_row4_col1" class="data row4 col1" >انا خايف من النصر وحظه السييء 💔</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Baseline model (using pipeline)**

# %%
# Vectorizing and then model
vect = CountVectorizer(max_features=15000, encoding='utf-8')
clf = LogisticRegression(max_iter=10000)

# combine them to a pipeline
pipe = Pipeline(steps=[
        ('vectorizer', vect),
        ('classifier', clf)
    ])

# fitting to train data
pipe.fit(df_train['tweet'], df_train['label'])
# Out:
# Pipeline(steps=[('vectorizer', CountVectorizer(max_features=15000)),
#                 ('classifier', LogisticRegression(max_iter=10000))])

# %%
df_train['label'].value_counts()   # balanced dataset
# Out:
# label
# pos    22761
# neg    22514
# Name: count, dtype: int64

# %%
# predict on test
y_pred_test = pipe.predict(df_test['tweet'])
print(f'Accuracy is {accuracy_score(df_test["label"], y_pred_test) * 100:.3f} %')
# Out:
# Accuracy is 77.274 %

# %% [markdown]
# **Try on some tweets**

# %%
for _, row in df_test.sample(5).iterrows():
    print(f"True label: {row['label']}")
    display(eli5.show_prediction(clf, row['tweet'], vec=vect, top=10, feature_names=vect.get_feature_names_out()))
    print("--"*50)

# Green: Features that support the predicted class. These features increase the likelihood of the model predicting the shown class.
# Red: Features that support the opposite class. These features decrease the likelihood of the model predicting the shown class.
# Out:
# True label: neg
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=neg
#
# </b>
#
#
#     (probability <b>0.733</b>, score <b>-1.010</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.698
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.63%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.312
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(0, 100.00%, 90.53%); opacity: 0.83" title="-0.203">الله</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="1.588">يرحمه</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.60%); opacity: 0.81" title="0.068">ويغفر</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.28%); opacity: 0.80" title="-0.034">له</span><span style="opacity: 0.80"> 😢 ولأمي </span><span style="background-color: hsl(120, 100.00%, 97.34%); opacity: 0.80" title="0.033">وموتى</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 76.25%); opacity: 0.89" title="-0.754">المسلمين</span>
#     </p>
# ----------------------------------------------------------------------------------------------------
# True label: neg
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=neg
#
# </b>
#
#
#     (probability <b>0.872</b>, score <b>-1.917</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.735
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 93.99%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.312
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 93.99%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 1 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 4 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">لاحظ </span><span style="background-color: hsl(0, 100.00%, 87.60%); opacity: 0.84" title="-0.112">في</span><span style="opacity: 0.80"> الاوانة </span><span style="background-color: hsl(120, 100.00%, 71.93%); opacity: 0.92" title="0.360">الأخيرة</span><span style="opacity: 0.80"> تعلق </span><span style="background-color: hsl(120, 100.00%, 87.37%); opacity: 0.84" title="0.115">الناس</span><span style="opacity: 0.80"> بالقهوه </span><span style="background-color: hsl(120, 100.00%, 76.84%); opacity: 0.89" title="0.274">حتى</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 66.32%); opacity: 0.96" title="0.467">صغار</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 68.00%); opacity: 0.95" title="-0.435">السن</span><span style="opacity: 0.80"> مادري </span><span style="background-color: hsl(120, 100.00%, 60.11%); opacity: 1.00" title="0.595">هل</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 86.42%); opacity: 0.84" title="-0.128">هو</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.598">ادمان</span><span style="opacity: 0.80"> ومزاج ولا من باب البرستيج والت…</span>
#     </p>
# ----------------------------------------------------------------------------------------------------
# True label: pos
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=pos
#
# </b>
#
#
#     (probability <b>0.910</b>, score <b>2.311</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.622
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 95.50%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.312
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="1.895">يلاقيها</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.43%); opacity: 0.80" title="0.019">من</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 84.15%); opacity: 0.85" title="0.505">الاهلي</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.23%); opacity: 0.80" title="-0.007">ولا</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.43%); opacity: 0.80" title="0.019">من</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 91.94%); opacity: 0.82" title="0.192">البشير</span><span style="opacity: 0.80"> 😂</span>
#     </p>
# ----------------------------------------------------------------------------------------------------
# True label: pos
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=pos
#
# </b>
#
#
#     (probability <b>0.535</b>, score <b>0.141</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.401
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 2 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 83.25%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 3 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 83.25%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.312
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">أموت ولا </span><span style="background-color: hsl(120, 100.00%, 89.01%); opacity: 0.83" title="0.153">تدري</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 84.77%); opacity: 0.85" title="0.243">وأنت</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.966">قتلتني</span><span style="opacity: 0.80"> فلا </span><span style="background-color: hsl(0, 100.00%, 91.78%); opacity: 0.82" title="-0.101">أنا</span><span style="opacity: 0.80"> أبديها ولا </span><span style="background-color: hsl(120, 100.00%, 76.30%); opacity: 0.89" title="0.457">أنت</span><span style="opacity: 0.80"> تعلم .. </span><span style="background-color: hsl(120, 100.00%, 90.60%); opacity: 0.83" title="0.122">لساني</span><span style="opacity: 0.80"> وقلبي يكتمان هواكم </span><span style="background-color: hsl(0, 100.00%, 77.35%); opacity: 0.89" title="-0.429">ولكن</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 69.19%); opacity: 0.94" title="-0.665">دمعي</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 80.55%); opacity: 0.87" title="-0.345">بالهوى</span><span style="opacity: 0.80"> يتكلم.…</span>
#     </p>
# ----------------------------------------------------------------------------------------------------
# True label: neg
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=neg
#
# </b>
#
#
#     (probability <b>0.561</b>, score <b>-0.247</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.312
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 93.36%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.065
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 83.72%); opacity: 0.86" title="0.223">وحشتنا</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.78%); opacity: 0.81" title="0.032">يا</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 60.00%); opacity: 1.00" title="-0.806">محمد</span><span style="opacity: 0.80"> وشلونك </span><span style="background-color: hsl(120, 100.00%, 85.37%); opacity: 0.85" title="0.192">عساك</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.97%); opacity: 0.81" title="0.020">طيب</span><span style="opacity: 0.80"> 😭 #</span><span style="background-color: hsl(0, 100.00%, 79.65%); opacity: 0.88" title="-0.307">زلزل_الملعب_نصرنا_بيلعب</span><span style="opacity: 0.80"> #</span><span style="background-color: hsl(120, 100.00%, 68.19%); opacity: 0.94" title="0.581">النصر_الاتحاد</span><span style="opacity: 0.80"> #نبيها_فل_السبت #السهلاوي</span>
#     </p>
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# **Using TFIDF and SVC in one pipeline**

# %%
vect = TfidfVectorizer(analyzer='char_wb', ngram_range=(3, 5), min_df=0.01, max_df=0.5, max_features=10000)
clf = LinearSVC()
pipe_tfidf = Pipeline(steps=[
        ('vectorizer', vect),
        ('classifier', clf)
    ])
pipe_tfidf.fit(df_train['tweet'], df_train['label'])
# Out:
# Pipeline(steps=[('vectorizer',
#                  TfidfVectorizer(analyzer='char_wb', max_df=0.5,
#                                  max_features=10000, min_df=0.01,
#                                  ngram_range=(3, 5))),
#                 ('classifier', LinearSVC())])

# %%
# predict on test
y_pred_test = pipe_tfidf.predict(df_test['tweet'])
print(f'Accuracy is {accuracy_score(df_test["label"], y_pred_test) * 100:.3f} %')
# Out:
# Accuracy is 83.811 %

# %%
for _, row in df_test.sample(5).iterrows():
    print(f"True label: {row['label']}")
    display(eli5.show_prediction(clf, row['tweet'], vec=vect, top=10, feature_names=vect.get_feature_names_out()))
    print("--"*50)
# Out:
# True label: neg
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=neg
#
# </b>
#
#
#     (score <b>-0.778</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.197
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 36 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 33 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">معقولة</span><span style="background-color: hsl(120, 100.00%, 82.45%); opacity: 0.86" title="0.017"> </span><span style="background-color: hsl(0, 100.00%, 73.90%); opacity: 0.91" title="-0.030">الك</span><span style="background-color: hsl(0, 100.00%, 64.25%); opacity: 0.97" title="-0.047">ل</span><span style="opacity: 0.80">ام</span><span style="background-color: hsl(120, 100.00%, 82.45%); opacity: 0.86" title="0.017"> الك</span><span style="opacity: 0.80">بير هذا ي</span><span style="background-color: hsl(120, 100.00%, 63.57%); opacity: 0.97" title="0.048">طلع</span><span style="opacity: 0.80"> من ناصر القصبي 😳</span><span style="background-color: hsl(120, 100.00%, 69.87%); opacity: 0.93" title="0.037"> إل</span><span style="opacity: 0.80">لي</span><span style="background-color: hsl(120, 100.00%, 66.55%); opacity: 0.95" title="0.043"> ماي</span><span style="opacity: 0.80">عرف يجمع ك</span><span style="background-color: hsl(120, 100.00%, 65.97%); opacity: 0.96" title="0.044">لمت</span><span style="opacity: 0.80">ين على</span><span style="background-color: hsl(0, 100.00%, 69.94%); opacity: 0.93" title="-0.037"> </span><span style="background-color: hsl(0, 100.00%, 60.00%); opacity: 1.00" title="-0.055">بعض</span><span style="background-color: hsl(120, 100.00%, 66.85%); opacity: 0.95" title="0.042"> </span><span style="opacity: 0.80">في أي مقابلة تلفزيو</span><span style="background-color: hsl(0, 100.00%, 69.57%); opacity: 0.94" title="-0.037">نية </span><span style="opacity: 0.80">وتخلص المقابل…</span>
#     </p>
# ----------------------------------------------------------------------------------------------------
# True label: neg
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=neg
#
# </b>
#
#
#     (score <b>-2.935</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.020
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 98.37%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.084
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 97.30%); opacity: 0.80" title="0.021">ما</span><span style="background-color: hsl(120, 100.00%, 91.07%); opacity: 0.82" title="0.117"> </span><span style="background-color: hsl(120, 100.00%, 91.01%); opacity: 0.82" title="0.118">اه</span><span style="background-color: hsl(0, 100.00%, 93.68%); opacity: 0.81" title="-0.071">تم</span><span style="background-color: hsl(0, 100.00%, 94.22%); opacity: 0.81" title="-0.063"> </span><span style="background-color: hsl(0, 100.00%, 94.91%); opacity: 0.81" title="-0.052">خل</span><span style="background-color: hsl(0, 100.00%, 94.35%); opacity: 0.81" title="-0.061">ا</span><span style="opacity: 0.80">ص</span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.998"> 😔</span>
#     </p>
# ----------------------------------------------------------------------------------------------------
# True label: neg
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=neg
#
# </b>
#
#
#     (score <b>-3.357</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.406
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 11 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 98.50%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 12 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 98.50%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.084
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 93.44%); opacity: 0.82" title="0.024">مات</span><span style="opacity: 0.80">وقعت كذا ال</span><span style="background-color: hsl(120, 100.00%, 93.13%); opacity: 0.82" title="0.026">ن</span><span style="background-color: hsl(120, 100.00%, 97.96%); opacity: 0.80" title="0.005">ها</span><span style="background-color: hsl(0, 100.00%, 94.00%); opacity: 0.81" title="-0.021">ي</span><span style="opacity: 0.80">ه</span><span style="background-color: hsl(120, 100.00%, 72.76%); opacity: 0.92" title="0.186"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.322">:(</span><span style="background-color: hsl(120, 100.00%, 67.63%); opacity: 0.95" title="0.238"> </span><span style="opacity: 0.80">هيوك</span><span style="background-color: hsl(0, 100.00%, 94.59%); opacity: 0.81" title="-0.018">جي </span><span style="opacity: 0.80">انق دونغهي </span><span style="background-color: hsl(120, 100.00%, 91.03%); opacity: 0.82" title="0.038">وان</span><span style="opacity: 0.80">طخ</span><span style="background-color: hsl(120, 100.00%, 72.76%); opacity: 0.92" title="0.186"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.322">:(</span><span style="background-color: hsl(120, 100.00%, 69.61%); opacity: 0.94" title="0.218"> </span><span style="background-color: hsl(0, 100.00%, 94.18%); opacity: 0.81" title="-0.021">ود</span><span style="opacity: 0.80">ونغهي بينتقم له </span><span style="background-color: hsl(120, 100.00%, 91.03%); opacity: 0.82" title="0.038">وان</span><span style="opacity: 0.80">طخ برضو</span><span style="background-color: hsl(120, 100.00%, 72.76%); opacity: 0.92" title="0.186"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.322">:(</span>
#     </p>
# ----------------------------------------------------------------------------------------------------
# True label: neg
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=neg
#
# </b>
#
#
#     (score <b>-0.680</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.407
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 28 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 19 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">بغض النظر</span><span style="background-color: hsl(0, 100.00%, 73.98%); opacity: 0.91" title="-0.041"> عن </span><span style="opacity: 0.80">مض</span><span style="background-color: hsl(120, 100.00%, 68.74%); opacity: 0.94" title="0.053">مون</span><span style="opacity: 0.80"> ال</span><span style="background-color: hsl(120, 100.00%, 77.40%); opacity: 0.89" title="0.033">تويت</span><span style="opacity: 0.80">ة </span><span style="background-color: hsl(0, 100.00%, 73.29%); opacity: 0.91" title="-0.042">الل</span><span style="opacity: 0.80">ي 👎</span><span style="background-color: hsl(0, 100.00%, 67.13%); opacity: 0.95" title="-0.057"> </span><span style="background-color: hsl(0, 100.00%, 90.61%); opacity: 0.83" title="-0.009">لك</span><span style="background-color: hsl(120, 100.00%, 71.07%); opacity: 0.93" title="0.047">ن </span><span style="opacity: 0.80">فكرة المقارنة و انك ك</span><span style="background-color: hsl(0, 100.00%, 74.83%); opacity: 0.90" title="-0.039">مرا</span><span style="opacity: 0.80">ة لازم</span><span style="background-color: hsl(120, 100.00%, 69.62%); opacity: 0.94" title="0.051"> تك</span><span style="background-color: hsl(120, 100.00%, 78.47%); opacity: 0.88" title="0.031">وني </span><span style="opacity: 0.80">ك</span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.075">الر</span><span style="opacity: 0.80">جل ليعطيك صفة الافضلية،، محزنة و تست…</span>
#     </p>
# ----------------------------------------------------------------------------------------------------
# True label: neg
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=neg
#
# </b>
#
#
#     (score <b>-1.155</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.648
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 18 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 17 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">ٲليس من</span><span style="background-color: hsl(0, 100.00%, 91.86%); opacity: 0.82" title="-0.046"> الع</span><span style="opacity: 0.80">يب ان تحفظ</span><span style="background-color: hsl(0, 100.00%, 93.00%); opacity: 0.82" title="-0.037"> كل </span><span style="background-color: hsl(0, 100.00%, 90.22%); opacity: 0.83" title="-0.060">الأ</span><span style="opacity: 0.80">غاني .. وتكرر</span><span style="background-color: hsl(120, 100.00%, 93.29%); opacity: 0.82" title="0.035"> </span><span style="background-color: hsl(0, 100.00%, 96.66%); opacity: 0.81" title="-0.013">ن</span><span style="background-color: hsl(120, 100.00%, 91.98%); opacity: 0.82" title="0.045">فس</span><span style="background-color: hsl(120, 100.00%, 86.17%); opacity: 0.84" title="0.099"> </span><span style="background-color: hsl(120, 100.00%, 92.60%); opacity: 0.82" title="0.040">ا</span><span style="background-color: hsl(0, 100.00%, 94.14%); opacity: 0.81" title="-0.029">لس</span><span style="background-color: hsl(0, 100.00%, 89.20%); opacity: 0.83" title="-0.069">و</span><span style="opacity: 0.80">رة في</span><span style="background-color: hsl(0, 100.00%, 93.00%); opacity: 0.82" title="-0.037"> كل</span><span style="background-color: hsl(0, 100.00%, 86.88%); opacity: 0.84" title="-0.092"> </span><span style="background-color: hsl(0, 100.00%, 90.90%); opacity: 0.82" title="-0.054">صل</span><span style="opacity: 0.80">اة ..</span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.450"> 💔</span>
#     </p>
# ----------------------------------------------------------------------------------------------------

# %%
import joblib
joblib.dump(pipe_tfidf, 'model.pkl')
# Out:
# ['model.pkl']
